# %% [markdown]
# <a href="https://colab.research.google.com/github/vjshinde04/DBS/blob/main/CodeDissertation_Vijay_10553812.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STAGE 1: Data Acquisition

# %%
pip install investpy

# %%
# https://investpy.readthedocs.io/
import investpy
import pandas as pd
investpy.__version__,investpy.__author__
# Out:
# ('1.0.7', 'Alvaro Bartolome @ alvarobartt in GitHub')

# %%
# data1NSE = investpy.get_stock_historical_data(stock='NSE', country='India', from_date='01/01/2000', to_date='01/07/2021')

# %%
stocksIndia = investpy.stocks.get_stocks(country='India')

# %%
stocksIndia
# Out:
#      country                     name  ... currency symbol
# 0      india     Aditya Birla Capital  ...      INR   ADTB
# 1      india                  Hubtown  ...      INR   HUBT
# 2      india              3i Infotech  ...      INR   TIIN
# 3      india                 3M India  ...      INR   TMIN
# 4      india                ABB India  ...      INR    ABB
# ...      ...                      ...  ...      ...    ...
# 1706   india           G K P Printing  ...      INR   GKPP
# 1707   india         Vivid Mercantile  ...      INR   VIVD
# 1708   india            White Organic  ...      INR   WHIE
# 1709   india      Parshva Enterprises  ...      INR   PAHV
# 1710   india  SK International Export  ...      INR   SKIN
#
# [1711 rows x 6 columns]

# %%
indicesIndia = investpy.indices.get_indices(country='India')
indicesIndia
# Out:
#     country                     name  ...               class          market
# 0     india           BSE Healthcare  ...     primary_sectors   world_indices
# 1     india                 BSE Teck  ...     primary_sectors   world_indices
# 2     india          S&P BSE Finance  ...     primary_sectors   world_indices
# 3     india                   BSE IT  ...     primary_sectors   world_indices
# 4     india               BSE Metals  ...     primary_sectors   world_indices
# ..      ...                      ...  ...                 ...             ...
# 135   india             BNY India DR  ...       other_indices  global_indices
# 136   india  BNY Mellon India ADR TR  ...  additional_indices  global_indices
# 137   india            BNY India GDR  ...       other_indices  global_indices
# 138   india   BNY Mellon India DR TR  ...  additional_indices  global_indices
# 139   india      BNY India Select DR  ...       other_indices  global_indices
#
# [140 rows x 7 columns]

# %%
indicesIndia['name'].tolist()
# Out:
# ['BSE Healthcare',
#  'BSE Teck',
#  'S&P BSE Finance',
#  'BSE IT',
#  'BSE Metals',
#  'BSE Oil & Gas',
#  'BSE Power',
#  'BSE PSU',
#  'BSE Realty',
#  'India VIX',
#  'DJ BRIC India 15 Capped NTR',
#  'Nifty 200',
#  'Nifty 50 USD',
#  'Nifty 50 Value 20',
#  'Nifty 500',
#  'NIFTY Midcap 100',
#  'Nifty Midcap 50',
#  'Nifty Next 50',
#  'BSE FMCG',
#  'NIFTY Smallcap 100',
#  'Nifty 100',
#  'BSE Consumer Durables',
#  'Nifty FMCG',
#  'BSE Bankex',
#  'BNY India Select DR TR',
#  'BSE Sensex',
#  'Nifty 50',
#  'Nifty Auto',
#  'Nifty Bank',
#  'Nifty Commodities',
#  'Nifty Financial Services',
#  'Nifty Smallcap 250',
#  'Nifty India Consumption',
#  'Nifty Infrastructure',
#  'Nifty IT',
#  'Nifty Media',
#  'Nifty Metal',
#  'Nifty MNC',
#  'Nifty Pharma',
#  'Nifty PSU Bank',
#  'Nifty Realty',
#  'Nifty Services Sector',
#  'BSE Auto',
#  'BSE Capital Goods',
#  'BNY India Select DR',
#  'S&P BSE ALLCAP',
#  'BSE SmallCap',
#  'BSE CARBONEX',
#  'BSE Bharat 22',
# ...

# %%
#
indicesIndia.loc[indicesIndia['name'] == 'Nifty 50']
# Out:
#    country      name full_name symbol currency          class         market
# 26   india  Nifty 50  Nifty 50   NSEI      INR  major_indices  world_indices

# %%
# indexInfo = investpy.indices.get_index_information(index='Nifty 50', country='india')
# indexInfo

# %%
indexHistData = investpy.indices.get_index_historical_data(index='Nifty 50', country='India', from_date='01/01/2000', to_date='01/07/2021')
indexHistData
# Out:
#                 Open      High       Low     Close     Volume Currency
# Date
# 2000-01-03   1482.15   1592.90   1482.15   1592.20   25358000      INR
# 2000-01-04   1594.40   1641.95   1594.40   1638.70   38788000      INR
# 2000-01-05   1634.55   1635.50   1555.05   1595.80   62153000      INR
# 2000-01-06   1595.80   1639.00   1595.80   1617.60   51273000      INR
# 2000-01-07   1616.60   1628.25   1597.20   1613.30   54316000      INR
# ...              ...       ...       ...       ...        ...      ...
# 2021-06-25  15839.35  15870.80  15772.30  15860.35  314609984      INR
# 2021-06-28  15915.35  15915.65  15792.15  15814.70  255100000      INR
# 2021-06-29  15807.50  15835.90  15724.05  15748.45  360329984      INR
# 2021-06-30  15776.90  15839.10  15708.75  15721.50  262390000      INR
# 2021-07-01  15755.05  15755.55  15667.05  15680.00  224920000      INR
#
# [5348 rows x 6 columns]

# %%
type(indexHistData)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
ax = plt.gca()
plt.ylabel('Stock price')
plt.title('NIFTY 50 close price')
indexHistData.plot(kind='line',y='Close',ax=ax)

# %%
# investpy.indices.get_indices_list
# and then
# investpy.indices.get_indices
# investpy.indices.get_index_historical_data

# %%
indexGlobalList = investpy.indices.get_indices_list()
indexGlobalList
# Out:
# ['S&P Merval',
#  'BNY Mellon Argentina ADR TR',
#  'BNY Mellon Argentina ADR',
#  'MAE Fixed Income',
#  'S&P/BYMA Argentina General',
#  'S&P Merval Argentina',
#  'S&P/BYMA Utilities',
#  'S&P/BYMA Real Estate',
#  'MSCI Argentina',
#  'S&P/BYMA Industrials',
#  'S&P/BYMA Financials',
#  'S&P/BYMA Energy',
#  'S&P/BYMA Consumer Staples',
#  'S&P/BYMA Communication Services',
#  'S&P/BYMA Consumer Discretionary',
#  'S&P/BYMA Materials',
#  'S&P ASX Financials x a r Accum',
#  'SP/ASX 100 Accum',
#  'SP/ASX 20 Accum',
#  'S&P/ASX 200 A Reit Equal Weight',
#  'S&P/ASX 200 Equal Weight',
#  'S&P/ASX 200 Net Total Return',
#  'S&P/ASX 200 Real Inverse Daily',
#  'S&P/ASX 200 VIX',
#  'S&P/ASX Buy Write',
#  'SP/ASX 50 Accum',
#  'S&P ASX Dividend Opportunities Accum',
#  'S&P/ASX Dividend Opportunities',
#  'S&P/ASX Emerging Companies',
#  'S&P/ASX Financials ex REIT',
#  'S&P/ASX Franked Dividend',
#  'S&P/ASX Small Ordinaries Resources',
#  'S&P/ASX 300 Shareholder Yield',
# ...

# %%
[index for index in indexGlobalList]
# Out:
# ['S&P Merval',
#  'BNY Mellon Argentina ADR TR',
#  'BNY Mellon Argentina ADR',
#  'MAE Fixed Income',
#  'S&P/BYMA Argentina General',
#  'S&P Merval Argentina',
#  'S&P/BYMA Utilities',
#  'S&P/BYMA Real Estate',
#  'MSCI Argentina',
#  'S&P/BYMA Industrials',
#  'S&P/BYMA Financials',
#  'S&P/BYMA Energy',
#  'S&P/BYMA Consumer Staples',
#  'S&P/BYMA Communication Services',
#  'S&P/BYMA Consumer Discretionary',
#  'S&P/BYMA Materials',
#  'S&P ASX Financials x a r Accum',
#  'SP/ASX 100 Accum',
#  'SP/ASX 20 Accum',
#  'S&P/ASX 200 A Reit Equal Weight',
#  'S&P/ASX 200 Equal Weight',
#  'S&P/ASX 200 Net Total Return',
#  'S&P/ASX 200 Real Inverse Daily',
#  'S&P/ASX 200 VIX',
#  'S&P/ASX Buy Write',
#  'SP/ASX 50 Accum',
#  'S&P ASX Dividend Opportunities Accum',
#  'S&P/ASX Dividend Opportunities',
#  'S&P/ASX Emerging Companies',
#  'S&P/ASX Financials ex REIT',
#  'S&P/ASX Franked Dividend',
#  'S&P/ASX Small Ordinaries Resources',
#  'S&P/ASX 300 Shareholder Yield',
# ...

# %%
for ind in indexGlobalList:
    print(ind)
# Out:
# Streaming output truncated to the last 5000 lines.
# Tel Bond Yields Shekel
# TASE Industry
# Tel Bond 40
# Tel Bond 60
# Tel Bond Composite
# Tel Bond Cpi Linked
# Tel Bond Cpi Linked Banks
# Tel Bond Cpi Linked Smallcap
# Tel Bond Floating
# Tel Bond Non Linked
# Tel Bond Yields
# TA Finance
# Tel Bond-CPI Linked 5-15
# TASE Banks
# Tel Bond 20
# TA Communications and IT
# TASE Invest Holdings
# TA Banks 5
# TASE Warrants
# Tel Div
# TA Biomed
# TA-SME150
# TA-Rimon
# TA Maala
# TASE Shares
# TASE Chemical
# TA 35 Galum
# TASE General
# Israel 50
# TA 35
# TASE Oil Gas Exploration
# TASE Commerce Services
# TASE Convertible Bonds
# USD/ILS Galum
# FTSE Israel
# TASE Real Estate Construction
# FTSE MIB
# FTSE Italia All Share Chemicals
# FTSE Italia All Share Health Care
# FTSE Italia All Share Industrials
# FTSE Italia All Share Travel & Leisure
# FTSE IT Oil&Gas
# FTSE IT Technology
# FTSE IT Telecom
# FTSE IT Utilities
# FTSE Italia All Share
# FTSE Italia All Share Financials
# ...

# %%
print(len(indexGlobalList))
# Out:
# 7800

# %%
indexGlobaldf = pd.DataFrame(indexGlobalList)
indexGlobaldf
# indexGlobaldf.to_csv(r'D:\code\DBSCode\CodeDissertation\indexGlobalList.csv', header=None, index = False)
# Out:
#                                 0
# 0                      S&P Merval
# 1     BNY Mellon Argentina ADR TR
# 2        BNY Mellon Argentina ADR
# 3                MAE Fixed Income
# 4      S&P/BYMA Argentina General
# ...                           ...
# 7795                LSE All Share
# 7796                       LSE EN
# 7797                      LSE Inv
# 7798              Zimbabwe Mining
# 7799          Zimbabwe Industrial
#
# [7800 rows x 1 columns]

# %%
investpy.indices.get_index_countries()
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'ivory coast',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'luxembourg',
#  'malawi',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestinian territory',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
#  'russia',
# ...

# %%
# Nifty 50:india
# Nifty Bank:india
# S&P 500:united states
# Nasdaq:united states
# Dow 30:united states
# Ibovespa USD:brazil
# DAX:germany
# FTSE 100:united kingdom
# S&P/ASX 200:australia
# Nikkei 225:japan
# TOPIX:japan
# KOSPI 200:south korea
# Taiwan Weighted:taiwan
# MSCI Singapore:singapore
# Hang Seng:hong kong
# China A50:china
# Shanghai:china
# India VIX:india
# S&P 500 VIX:united states

indexTargetDict = {'Nifty 50':'india', 'Nifty Bank':'india', 'S&P 500':'united states', 'Nasdaq':'united states', 
                   'Dow 30':'united states', 'ibovespa USD':'brazil', 'DAX':'germany', 'FTSE 100':'united kingdom', 
                   'S&P/ASX 200':'australia', 'Nikkei 225':'japan', 'TOPIX':'japan', 'KOSPI 200':'south korea', 
                   'Taiwan Weighted':'taiwan', 'MSCI Singapore':'singapore', 'Hang Seng':'hong kong', 
                   'China A50':'china', 'Shanghai':'china', 'India VIX':'india', 'S&P 500 VIX':'united states'}
print(len(indexTargetDict))
# Out:
# 19

# %%
# indicesTargetDetails = investpy.indices.get_indices
# indicesTargetData = investpy.indices.get_index_historical_data

# %%
# # indicesTargetDetails = []
# for key, value in indexTargetDict.items():
#     print("\n\n",key)
#     indicesTargetDetails = investpy.indices.get_index_information(index=key, country=value)
#     print(indicesTargetDetails)

# %%
# https://stackoverflow.com/questions/13784192/creating-an-empty-pandas-dataframe-then-filling-it
indexHistData = []
for key, value in indexTargetDict.items():
    print("{}: {}".format(key, value))
    histData = investpy.indices.get_index_historical_data(index=key, country=value, from_date='01/01/2000', to_date='01/07/2021')
#     if key=="S&P/ASX 200":
#         histData.to_csv(r'D:\code\DBSCode\CodeDissertation\histData_ASX 200.csv', index = True)
#     else:
#         histData.to_csv(r'D:\code\DBSCode\CodeDissertation\histData_'+key+'.csv', index = True)
    histData['IndexName']=key
    histData['Country']=value
    indexHistData.append(histData)
#     print(indexHistData)
    
indexTargetHistData = pd.concat(indexHistData, ignore_index = False)
# Out:
# Nifty 50: india
# Nifty Bank: india
# S&P 500: united states
# Nasdaq: united states
# Dow 30: united states
# ibovespa USD: brazil
# DAX: germany
# FTSE 100: united kingdom
# S&P/ASX 200: australia
# Nikkei 225: japan
# TOPIX: japan
# KOSPI 200: south korea
# Taiwan Weighted: taiwan
# MSCI Singapore: singapore
# Hang Seng: hong kong
# China A50: china
# Shanghai: china
# India VIX: india
# S&P 500 VIX: united states

# %%
print(len(indexTargetHistData))
indexTargetHistData.sample(5)
# Out:
# 81395
#                 Open        High  ...    IndexName         Country
# Date                              ...
# 2001-02-08   3312.10   3331.5000  ...  S&P/ASX 200       australia
# 2016-12-01   6783.79   6789.3000  ...     FTSE 100  united kingdom
# 2002-11-18   3195.97   3262.0800  ...          DAX         germany
# 2018-04-16     14.14     14.8625  ...    India VIX           india
# 2019-12-27  14139.42  14301.6600  ...    China A50           china
#
# [5 rows x 8 columns]

# %%
# indexTargetHistData.to_csv(r'D:\code\DBSCode\CodeDissertation\indexTargetHistData.csv', index = True)

# %% [markdown]
# # STAGE 2: Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset and examining it
# jupyter
# df = pd.read_csv("indexTargetHistData.csv")
# colab
df = indexTargetHistData
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81395 entries, 2000-01-03 to 2021-07-01
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       81395 non-null  float64
#  1   High       81395 non-null  float64
#  2   Low        81395 non-null  float64
#  3   Close      81395 non-null  float64
#  4   Volume     81395 non-null  int64
#  5   Currency   81395 non-null  object
#  6   IndexName  81395 non-null  object
#  7   Country    81395 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 5.6+ MB

# %%
df.head()
# Out:
#                Open     High      Low  ...  Currency  IndexName Country
# Date                                   ...
# 2000-01-03  1482.15  1592.90  1482.15  ...       INR   Nifty 50   india
# 2000-01-04  1594.40  1641.95  1594.40  ...       INR   Nifty 50   india
# 2000-01-05  1634.55  1635.50  1555.05  ...       INR   Nifty 50   india
# 2000-01-06  1595.80  1639.00  1595.80  ...       INR   Nifty 50   india
# 2000-01-07  1616.60  1628.25  1597.20  ...       INR   Nifty 50   india
#
# [5 rows x 8 columns]

# %%
# colab
df['Date'] = df.index

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')

# %%
# colab
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#       Open     High      Low   Close  ...  Currency IndexName Country       Date
# 0  1482.15  1592.90  1482.15  1592.2  ...       INR  Nifty 50   india 2000-01-03
# 1  1594.40  1641.95  1594.40  1638.7  ...       INR  Nifty 50   india 2000-01-04
# 2  1634.55  1635.50  1555.05  1595.8  ...       INR  Nifty 50   india 2000-01-05
# 3  1595.80  1639.00  1595.80  1617.6  ...       INR  Nifty 50   india 2000-01-06
# 4  1616.60  1628.25  1597.20  1613.3  ...       INR  Nifty 50   india 2000-01-07
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81395 entries, 0 to 81394
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       81395 non-null  float64
#  1   High       81395 non-null  float64
#  2   Low        81395 non-null  float64
#  3   Close      81395 non-null  float64
#  4   Volume     81395 non-null  int64
#  5   Currency   81395 non-null  object
#  6   IndexName  81395 non-null  object
#  7   Country    81395 non-null  object
#  8   Date       81395 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 5.6+ MB

# %%
df.sample(5)
# Out:
#           Open     High      Low  ...    IndexName        Country       Date
# 76504    25.26    26.19    24.51  ...  S&P 500 VIX  united states 2002-02-05
# 47405  1737.57  1745.70  1727.44  ...        TOPIX          japan 2018-03-15
# 64810  9073.02  9189.30  8989.90  ...    China A50          china 2010-09-01
# 65810  7237.98  7309.19  7216.13  ...    China A50          china 2014-10-08
# 47343  1814.34  1820.86  1810.93  ...        TOPIX          japan 2017-12-12
#
# [5 rows x 9 columns]

# %%
# df.index = df['Date']
# del df['Date']
# df.head()

# %%
indexNames = df['IndexName'].unique()
print(indexNames)
print(len(indexNames))
# Out:
# ['Nifty 50' 'Nifty Bank' 'S&P 500' 'Nasdaq' 'Dow 30' 'ibovespa USD' 'DAX'
#  'FTSE 100' 'S&P/ASX 200' 'Nikkei 225' 'TOPIX' 'KOSPI 200'
#  'Taiwan Weighted' 'MSCI Singapore' 'Hang Seng' 'China A50' 'Shanghai'
#  'India VIX' 'S&P 500 VIX']
# 19

# %%
countryNames = df['Country'].unique()
print(countryNames)
print(len(countryNames))
# Out:
# ['india' 'united states' 'brazil' 'germany' 'united kingdom' 'australia'
#  'japan' 'south korea' 'taiwan' 'singapore' 'hong kong' 'china']
# 12

# %%
currencyNames = df['Currency'].unique()
print(currencyNames)
print(len(currencyNames))
# Out:
# ['INR' 'USD' 'BRL' 'EUR' 'GBP' 'AUD' 'JPY' 'KRW' 'TWD' 'SGD' 'HKD' 'CNY']
# 12

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (16,10))
sns.lineplot(data=df, x='Date', y='Close', hue='IndexName')
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)
# Out:
# CPU times: user 4.53 s, sys: 21.8 ms, total: 4.55 s
# Wall time: 4.58 s

# %%
# %%time
sns.relplot(data=df, kind='line', x='Date', y='Close', col='IndexName', col_wrap=2)
# Out:
# CPU times: user 7.66 s, sys: 188 ms, total: 7.85 s
# Wall time: 7.75 s

# %%
# for name, data in df.groupby('IndexName'):
#     plt.plot(data['Date'], data['Close'], label=name)
#     plt.xlabel('Date')
#     plt.ylabel('Close')
#     plt.legend()
#     if name=="S&P/ASX 200":
#         plt.savefig('plot_ASX 200.png')
#     else:
#         plt.savefig('plot_{}.png'.format(name))
#     plt.close()

# %%
for name, data in df.groupby('IndexName'):
    print('{:<20}{}'.format(name, data['Date'].min()))
# Out:
# China A50           2004-03-05 00:00:00
# DAX                 2001-01-03 00:00:00
# Dow 30              2000-01-03 00:00:00
# FTSE 100            2001-01-03 00:00:00
# Hang Seng           2000-12-05 00:00:00
# India VIX           2008-03-04 00:00:00
# KOSPI 200           2000-12-26 00:00:00
# MSCI Singapore      2012-07-09 00:00:00
# Nasdaq              2000-01-03 00:00:00
# Nifty 50            2000-01-03 00:00:00
# Nifty Bank          2005-06-10 00:00:00
# Nikkei 225          2001-01-05 00:00:00
# S&P 500             2006-01-04 00:00:00
# S&P 500 VIX         2000-01-03 00:00:00
# S&P/ASX 200         2000-01-04 00:00:00
# Shanghai            2000-01-04 00:00:00
# TOPIX               2011-08-17 00:00:00
# Taiwan Weighted     2011-03-17 00:00:00
# ibovespa USD        2018-02-19 00:00:00

# %%
closeData = df.pivot(index='Date', columns='IndexName')['Close']
closeData.head()
# Out:
# IndexName   China A50  DAX    Dow 30  ...  TOPIX  Taiwan Weighted  ibovespa USD
# Date                                  ...
# 2000-01-03        NaN  NaN  11357.51  ...    NaN              NaN           NaN
# 2000-01-04        NaN  NaN  10997.94  ...    NaN              NaN           NaN
# 2000-01-05        NaN  NaN  11122.66  ...    NaN              NaN           NaN
# 2000-01-06        NaN  NaN  11253.27  ...    NaN              NaN           NaN
# 2000-01-07        NaN  NaN  11522.56  ...    NaN              NaN           NaN
#
# [5 rows x 19 columns]

# %%
closeData.sample(5)
# Out:
# IndexName   China A50       DAX  ...  Taiwan Weighted  ibovespa USD
# Date                             ...
# 2010-09-24        NaN   6298.30  ...              NaN           NaN
# 2017-03-17   10346.30  12095.24  ...          9908.69           NaN
# 2012-05-21    8070.02   6331.04  ...          7192.23           NaN
# 2009-07-15   12105.97   4928.44  ...              NaN           NaN
# 2003-07-15        NaN   3384.69  ...              NaN           NaN
#
# [5 rows x 19 columns]

# %%
indexCorr = closeData.corr()
indexCorr
# Out:
# IndexName        China A50       DAX  ...  Taiwan Weighted  ibovespa USD
# IndexName                             ...
# China A50         1.000000  0.632619  ...         0.888274     -0.055156
# DAX               0.632619  1.000000  ...         0.845264      0.230983
# Dow 30            0.608719  0.946806  ...         0.916671      0.186971
# FTSE 100          0.486711  0.891274  ...         0.455976      0.704792
# Hang Seng         0.769810  0.875121  ...         0.728203      0.543734
# India VIX        -0.116301 -0.554896  ...        -0.044756     -0.642993
# KOSPI 200         0.669808  0.864508  ...         0.898793      0.039243
# MSCI Singapore   -0.077135  0.072528  ...        -0.026687      0.740898
# Nasdaq            0.608387  0.901333  ...         0.958811     -0.195340
# Nifty 50          0.665609  0.956971  ...         0.921028      0.258306
# Nifty Bank        0.541424  0.938058  ...         0.845171      0.599298
# ...

# %%
plt.figure(figsize = (16,10))

mask = np.zeros_like(indexCorr)
mask[np.triu_indices_from(mask)] = True

plt.title('Correlation heatmap')
sns.heatmap(indexCorr, cmap='viridis', square=True, mask=mask)

# %% [markdown]
# # STAGE 3: Data Preparation

# %%
#dropping MSCI Singapore since its inception is from 2012(we are taking data from 2010 onwards) 
# + coorrelation with NIFTY50 is too small
df[df['IndexName'] == 'MSCI Singapore']
# Out:
#           Open     High      Low  ...       IndexName    Country       Date
# 55815  1590.51  1592.90  1576.01  ...  MSCI Singapore  singapore 2012-07-09
# 55816  1583.43  1596.10  1578.17  ...  MSCI Singapore  singapore 2012-07-10
# 55817  1582.46  1612.49  1582.46  ...  MSCI Singapore  singapore 2012-07-11
# 55818  1601.95  1605.78  1593.37  ...  MSCI Singapore  singapore 2012-07-12
# 55819  1595.80  1610.19  1595.25  ...  MSCI Singapore  singapore 2012-07-13
# ...        ...      ...      ...  ...             ...        ...        ...
# 58121  1659.43  1665.41  1654.03  ...  MSCI Singapore  singapore 2021-06-25
# 58122  1666.64  1667.34  1660.43  ...  MSCI Singapore  singapore 2021-06-28
# 58123  1658.80  1658.80  1638.93  ...  MSCI Singapore  singapore 2021-06-29
# 58124  1647.40  1671.89  1644.58  ...  MSCI Singapore  singapore 2021-06-30
# 58125  1668.84  1671.98  1659.03  ...  MSCI Singapore  singapore 2021-07-01
#
# [2311 rows x 9 columns]

# %%
len(df)
# Out:
# 81395

# %%
df.drop(df[df['IndexName'] == 'MSCI Singapore'].index, inplace=True)
len(df)
# Out:
# 79084

# %%
df.drop(df[df['IndexName'] == 'ibovespa USD'].index, inplace=True)
len(df)
# Out:
# 78257

# %%
df[df['Date'] > '2010-01-01']
# Out:
#           Open     High      Low  ...    IndexName        Country       Date
# 2496   5200.90  5238.45  5167.10  ...     Nifty 50          india 2010-01-04
# 2497   5277.15  5288.35  5242.40  ...     Nifty 50          india 2010-01-05
# 2498   5278.15  5310.85  5260.05  ...     Nifty 50          india 2010-01-06
# 2499   5281.80  5302.55  5244.75  ...     Nifty 50          india 2010-01-07
# 2500   5264.25  5276.75  5234.70  ...     Nifty 50          india 2010-01-08
# ...        ...      ...      ...  ...          ...            ...        ...
# 81390    16.04    16.17    15.21  ...  S&P 500 VIX  united states 2021-06-25
# 81391    16.07    16.46    15.39  ...  S&P 500 VIX  united states 2021-06-28
# 81392    15.69    16.31    14.10  ...  S&P 500 VIX  united states 2021-06-29
# 81393    16.18    17.31    15.58  ...  S&P 500 VIX  united states 2021-06-30
# 81394    15.62    16.01    15.31  ...  S&P 500 VIX  united states 2021-07-01
#
# [48006 rows x 9 columns]

# %%
#Taking data from 2010 onwards
df.drop(df[df['Date'] < '2010-01-01'].index, inplace=True, errors='ignore')
len(df)
df.shape
# Out:
# (48006, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48006 entries, 2496 to 81394
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       48006 non-null  float64
#  1   High       48006 non-null  float64
#  2   Low        48006 non-null  float64
#  3   Close      48006 non-null  float64
#  4   Volume     48006 non-null  int64
#  5   Currency   48006 non-null  object
#  6   IndexName  48006 non-null  object
#  7   Country    48006 non-null  object
#  8   Date       48006 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 3.7+ MB

# %%
categoricalCol= ['Currency','IndexName', 'Country']
encodedDF = pd.get_dummies(df, columns = categoricalCol)
encodedDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48006 entries, 2496 to 81394
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Open                       48006 non-null  float64
#  1   High                       48006 non-null  float64
#  2   Low                        48006 non-null  float64
#  3   Close                      48006 non-null  float64
#  4   Volume                     48006 non-null  int64
#  5   Date                       48006 non-null  datetime64[ns]
#  6   Currency_AUD               48006 non-null  uint8
#  7   Currency_CNY               48006 non-null  uint8
#  8   Currency_EUR               48006 non-null  uint8
#  9   Currency_GBP               48006 non-null  uint8
#  10  Currency_HKD               48006 non-null  uint8
#  11  Currency_INR               48006 non-null  uint8
#  12  Currency_JPY               48006 non-null  uint8
# ...

# %%
encodedDF.shape
# Out:
# (48006, 43)

# %%
encodedDF.sample(5)
# Out:
#            Open      High  ...  Country_united kingdom  Country_united states
# 46109    777.37    779.87  ...                       0                      0
# 27533   7075.91   7123.88  ...                       0                      0
# 27896   7425.08   7434.96  ...                       0                      0
# 53869   8114.51   8162.91  ...                       0                      0
# 66010  12033.63  12268.28  ...                       0                      0
#
# [5 rows x 43 columns]

# %%
encodedDF['Date'].max()
# Out:
# Timestamp('2021-07-01 00:00:00')

# %%
encodedDF[(encodedDF['IndexName_Nifty 50'] == 1) & (encodedDF['Date'] > '2021-05-01')]
# Out:
#           Open      High  ...  Country_united kingdom  Country_united states
# 5305  14481.05  14673.85  ...                       0                      0
# 5306  14687.25  14723.40  ...                       0                      0
# 5307  14604.15  14637.90  ...                       0                      0
# 5308  14668.35  14743.90  ...                       0                      0
# 5309  14816.85  14863.05  ...                       0                      0
# 5310  14928.25  14966.90  ...                       0                      0
# 5311  14789.70  14900.00  ...                       0                      0
# 5312  14823.55  14824.05  ...                       0                      0
# 5313  14749.40  14749.65  ...                       0                      0
# 5314  14756.25  14938.00  ...                       0                      0
# 5315  15067.20  15137.25  ...                       0                      0
# ...

# %%
test = encodedDF[(encodedDF['IndexName_Nifty 50'] == 1) & (encodedDF['Date'] > '2021-05-01')]

# %%
train = encodedDF.drop(encodedDF[(encodedDF['IndexName_Nifty 50'] == 1) & (encodedDF['Date'] > '2021-05-01')].index)

# %%
print(len(encodedDF))
print(len(train))
print(len(test))
print(len(train)+len(test))
# Out:
# 48006
# 47963
# 43
# 48006

# %%
print('Dimensions : \ntrain set: {}\ntest set : {}'.format(train.shape,test.shape))
# Out:
# Dimensions :
# train set: (47963, 43)
# test set : (43, 43)

# %%
# %%time
plt.figure(figsize = (16,10))
sns.lineplot(data=train[train['IndexName_Nifty 50'] == 1], x='Date', y='Close', label='Train set')
sns.lineplot(data=test[test['IndexName_Nifty 50'] == 1], x='Date', y='Close', color='red', label='Test set')
plt.title('Train/Test split for Nifty 50 stock price')
plt.ylabel('Close price')
# Out:
# CPU times: user 221 ms, sys: 973 µs, total: 222 ms
# Wall time: 224 ms

# %%
print(train.info())
train.index = train['Date']
del train['Date']
test.index = test['Date']
del test['Date']
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47963 entries, 2496 to 81394
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Open                       47963 non-null  float64
#  1   High                       47963 non-null  float64
#  2   Low                        47963 non-null  float64
#  3   Close                      47963 non-null  float64
#  4   Volume                     47963 non-null  int64
#  5   Date                       47963 non-null  datetime64[ns]
#  6   Currency_AUD               47963 non-null  uint8
#  7   Currency_CNY               47963 non-null  uint8
#  8   Currency_EUR               47963 non-null  uint8
#  9   Currency_GBP               47963 non-null  uint8
#  10  Currency_HKD               47963 non-null  uint8
#  11  Currency_INR               47963 non-null  uint8
#  12  Currency_JPY               47963 non-null  uint8
# ...

# %%
print('Dimensions : \ntrain set: {}\ntest set : {}'.format(train.shape,test.shape))
# Out:
# Dimensions :
# train set: (47963, 42)
# test set : (43, 42)

# %%
train.sample(5)
# Out:
#                 Open      High  ...  Country_united kingdom  Country_united states
# Date                            ...
# 2018-06-12  25346.82  25364.37  ...                       0                      1
# 2020-05-21  10933.21  11021.66  ...                       0                      0
# 2020-01-10  12271.00  12311.20  ...                       0                      0
# 2017-11-17  10324.55  10343.60  ...                       0                      0
# 2015-08-24  19075.05  19154.65  ...                       0                      0
#
# [5 rows x 42 columns]

# %%
test.head(5)
# Out:
#                 Open      High  ...  Country_united kingdom  Country_united states
# Date                            ...
# 2021-05-03  14481.05  14673.85  ...                       0                      0
# 2021-05-04  14687.25  14723.40  ...                       0                      0
# 2021-05-05  14604.15  14637.90  ...                       0                      0
# 2021-05-06  14668.35  14743.90  ...                       0                      0
# 2021-05-07  14816.85  14863.05  ...                       0                      0
#
# [5 rows x 42 columns]

# %%
trainX = train.drop(['Close'], axis=1)
trainy = train['Close']
testX = test.drop(['Close'], axis=1)
testy = test['Close']
print('Dimensions : \ntrain set: {}\ntrainX set : {}\ntrainy set : {}\ntest set : {}\ntestX set : {}\ntesty set : {}'
      .format(train.shape,trainX.shape,trainy.shape,test.shape,testX.shape,testy.shape))
# Out:
# Dimensions :
# train set: (47963, 42)
# trainX set : (47963, 41)
# trainy set : (47963,)
# test set : (43, 42)
# testX set : (43, 41)
# testy set : (43,)

# %%
# Scaling the values for faster training of the models.
from sklearn.preprocessing import MinMaxScaler

scaledtrain = trainX
scalers={}

for i in trainX.columns:
    scaler = MinMaxScaler(feature_range=(0,1))
    s_s = scaler.fit_transform(scaledtrain[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+ i] = scaler
    scaledtrain[i]=s_s

scaledtest = testX
for i in testX.columns:
    scaler = scalers['scaler_'+i]
    s_s = scaler.transform(scaledtest[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+i] = scaler
    scaledtest[i]=s_s

# %%
scaledtrain.head(5)
# Out:
#                 Open      High  ...  Country_united kingdom  Country_united states
# Date                            ...
# 2010-01-04  0.138511  0.138706  ...                     0.0                    0.0
# 2010-01-05  0.140545  0.140030  ...                     0.0                    0.0
# 2010-01-06  0.140572  0.140626  ...                     0.0                    0.0
# 2010-01-07  0.140669  0.140406  ...                     0.0                    0.0
# 2010-01-08  0.140201  0.139722  ...                     0.0                    0.0
#
# [5 rows x 41 columns]

# %%
trainX = scaledtrain
testX = scaledtest

# %%
trainy.sample(5)
# Out:
# Date
# 2016-01-18    16955.57
# 2010-06-02    10249.54
# 2012-04-26      810.10
# 2020-07-02      283.86
# 2011-07-01     2759.36
# Name: Close, dtype: float64

# %%
for colNames in trainX.columns:
  print(colNames)
# Out:
# Open
# High
# Low
# Volume
# Currency_AUD
# Currency_CNY
# Currency_EUR
# Currency_GBP
# Currency_HKD
# Currency_INR
# Currency_JPY
# Currency_KRW
# Currency_TWD
# Currency_USD
# IndexName_China A50
# IndexName_DAX
# IndexName_Dow 30
# IndexName_FTSE 100
# IndexName_Hang Seng
# IndexName_India VIX
# IndexName_KOSPI 200
# IndexName_Nasdaq
# IndexName_Nifty 50
# IndexName_Nifty Bank
# IndexName_Nikkei 225
# IndexName_S&P 500
# IndexName_S&P 500 VIX
# IndexName_S&P/ASX 200
# IndexName_Shanghai
# IndexName_TOPIX
# IndexName_Taiwan Weighted
# Country_australia
# Country_china
# Country_germany
# Country_hong kong
# Country_india
# Country_japan
# Country_south korea
# Country_taiwan
# Country_united kingdom
# Country_united states

# %% [markdown]
# # STAGE 4: Prediction

# %% [markdown]
# ### Prediction Model 1: Linear Regression

# %%
from sklearn.linear_model import LinearRegression
modelLinearReg = LinearRegression()
modelLinearReg.fit(trainX,trainy)
predy = modelLinearReg.predict(testX)

# %%
from math import sqrt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(testy,predy)
print('MAE:', mae)

rmse = sqrt(mean_squared_error(testy,predy))
print('RMSE:', rmse)

score = r2_score(testy, predy)
print("Accuracy: %.2f%%" % (score * 100.0))
# Out:
# MAE: 30.563372093023265
# RMSE: 43.50435607031817
# Accuracy: 98.96%

# %%
testX['Predictions'] = 0
testX['Predictions'] = predy

plt.figure(figsize = (16,10))
sns.lineplot(data=test[test['IndexName_Nifty 50'] == 1], x=test.index, y='Close', label = 'Actual Close price')
plt.plot(testX['Predictions'], label = 'Predictions')
plt.legend()

# %%
print('Dimensions : \ntrainX set: {}\ntestX set : {}'.format(trainX.shape,testX.shape))
testX.drop(['Predictions'], axis=1,inplace=True)
print('Dimensions : \ntrainX set: {}\ntestX set : {}'.format(trainX.shape,testX.shape))
# Out:
# Dimensions :
# trainX set: (47963, 41)
# testX set : (43, 42)
# Dimensions :
# trainX set: (47963, 41)
# testX set : (43, 41)

# %% [markdown]
# ### Prediction Model 2: xGBoost Regression

# %%
from xgboost import XGBRegressor
modelxGBRegressor = XGBRegressor()
modelxGBRegressor.fit(trainX, trainy)
# Out:
# [20:53:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predy = modelxGBRegressor.predict(testX)

# %%
mae = mean_absolute_error(testy,predy)
print('MAE:', mae)

rmse = sqrt(mean_squared_error(testy,predy))
print('RMSE: ', rmse)

score = r2_score(testy, predy)
print("Accuracy: %.2f%%" % (score * 100.0))
# Out:
# MAE: 72.56261355377912
# RMSE:  89.13571504237638
# Accuracy: 95.65%

# %%
testX['Predictions'] = 0
testX['Predictions'] = predy

plt.figure(figsize = (16,10))
plt.title('NIFTY 50 prediction using XGBoost Regression model')
sns.lineplot(data=test[test['IndexName_Nifty 50'] == 1], x=test.index, y='Close', label = 'Actual Close price')
plt.plot(testX['Predictions'], label = 'Predictions')
plt.legend()

# %%
print('Dimensions : \ntrainX set: {}\ntestX set : {}'.format(trainX.shape,testX.shape))
testX.drop(['Predictions'], axis=1,inplace=True)
print('Dimensions : \ntrainX set: {}\ntestX set : {}'.format(trainX.shape,testX.shape))
# Out:
# Dimensions :
# trainX set: (47963, 41)
# testX set : (43, 42)
# Dimensions :
# trainX set: (47963, 41)
# testX set : (43, 41)

# %% [markdown]
# ### Prediction Model 3: LSTM

# %%
trainX = trainX.values.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.values.reshape((testX.shape[0], 1, testX.shape[1]))
print('Dimensions : \ntrainX set : {}\ntrainy set : {}\ntestX set : {}\ntesty set : {}'
      .format(trainX.shape,trainy.shape,testX.shape,testy.shape))
# Out:
# Dimensions :
# trainX set : (47963, 1, 41)
# trainy set : (47963,)
# testX set : (43, 1, 41)
# testy set : (43,)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

modelLSTM = Sequential()
modelLSTM.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
modelLSTM.add(Dense(1))
modelLSTM.compile(loss='mae', optimizer='adam')
# fit network
history = modelLSTM.fit(trainX, trainy, epochs=50, batch_size=72, validation_data=(testX, testy), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 667/667 - 3s - loss: 8360.5938 - val_loss: 15357.1221
# Epoch 2/50
# 667/667 - 1s - loss: 8333.3691 - val_loss: 15325.0381
# Epoch 3/50
# 667/667 - 1s - loss: 8308.4482 - val_loss: 15298.5752
# Epoch 4/50
# 667/667 - 1s - loss: 8283.7422 - val_loss: 15270.9883
# Epoch 5/50
# 667/667 - 1s - loss: 8260.1621 - val_loss: 15245.2031
# Epoch 6/50
# 667/667 - 1s - loss: 8237.4873 - val_loss: 15220.0068
# Epoch 7/50
# 667/667 - 1s - loss: 8215.2617 - val_loss: 15195.1934
# Epoch 8/50
# 667/667 - 1s - loss: 8193.3477 - val_loss: 15170.6074
# Epoch 9/50
# 667/667 - 1s - loss: 8171.7812 - val_loss: 15146.3486
# Epoch 10/50
# 667/667 - 1s - loss: 8151.0366 - val_loss: 15123.0146
# Epoch 11/50
# 667/667 - 1s - loss: 8132.1714 - val_loss: 15100.8086
# Epoch 12/50
# 667/667 - 1s - loss: 8114.6465 - val_loss: 15079.0508
# Epoch 13/50
# 667/667 - 1s - loss: 8097.6733 - val_loss: 15057.6211
# Epoch 14/50
# 667/667 - 1s - loss: 8080.9463 - val_loss: 15036.3564
# Epoch 15/50
# ...

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = modelLSTM.predict(testX)
testX = testX.reshape((testX.shape[0], testX.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, testX[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
testy = testy.values.reshape((len(testy), 1))
inv_y = np.concatenate((testy, testX[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
mae = mean_absolute_error(inv_y, inv_yhat)
print('MAE:', mae)

rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('RMSE: ', rmse)

score = r2_score(inv_y, inv_yhat)
print("Accuracy: %.2f%%" % (score * 100.0))
# Out:
# MAE: 14219.684876339932
# RMSE:  14226.100274711966
# Accuracy: -110799.54%

# %% [markdown]
# # STAGE 5: XAI/Interpretability

# %% [markdown]
# ### XAI Method 1: Shapash

# %%
pip install shapash
# Out:
# ...
#      |████████████████████████████████| 877 kB 31.2 MB/s
# ...
#      |████████████████████████████████| 356 kB 58.9 MB/s
# ...
#      |████████████████████████████████| 75 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 55.0 MB/s
# ...
#      |████████████████████████████████| 99 kB 10.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.4 MB 49.7 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 52.8 MB/s
# ...
#      |████████████████████████████████| 188 kB 57.2 MB/s
# ...
#      |████████████████████████████████| 13.1 MB 49 kB/s
# ...
#      |████████████████████████████████| 3.5 MB 60.0 MB/s
# ...
#      |████████████████████████████████| 642 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 25.3 MB 59 kB/s
# ...
#      |████████████████████████████████| 357 kB 51.2 MB/s
# ...

# %%
## https://pypi.org/project/shapash/

import shapash
import shap
from shapash.utils.load_smartpredictor import load_smartpredictor
from shapash.explainer.smart_explainer import SmartExplainer

# %%
############## Linear Regression #############
# create explainer
xpl = SmartExplainer()
xpl.compile(
    x=testX,
    model=modelLinearReg,
#     y_pred = predy
)
#Creating Application
app = xpl.run_app(title_story='Nifty 50 Prediction')

############## visualizations #############
# feature importance based on SHAP
xpl.plot.features_importance()

# xpl.plot.compare_plot(row_num=[0,1,2])

# # contributions plot
# xpl.plot.contribution_plot("OverallQual")

# # Interactive interactions widget 
# xpl.plot.top_interactions_plot(nb_top_interactions=5)

# # save contributions
# predictor = xpl.to_smartpredictor()
# predictor.add_input(x=trainX, ypred=trainy)
# detailed_contributions = predictor.detail_contributions()
# Out:
# Backend: Shap LinearExplainer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-7e83b2eece5a> in <module>()
#       4 xpl.compile(
#       5     x=testX,
# ----> 6     model=modelLinearReg,
#       7 #     y_pred = predy
#       8 )
#
# /usr/local/lib/python3.7/dist-packages/shapash/explainer/smart_explainer.py in compile(self, x, model, explainer, contributions, y_pred, preprocessing, postprocessing, title_story, features_groups, backend, **kwargs)
#     239         adapt_contrib = self.adapt_contributions(contributions)
#     240         self.state = self.choose_state(adapt_contrib)
# --> 241         self.contributions = self.apply_preprocessing(self.validate_contributions(adapt_contrib), preprocessing)
#     242         self.check_contributions()
#     243         self.explainer = explainer
#
# ...

# %%
############## XGBoost Regression #############
# create explainer
xpl = SmartExplainer()
xpl.compile(
    x=testX,
    model=modelxGBRegressor,
#     y_pred = predy
)
#Creating Application
app = xpl.run_app(title_story='Nifty 50 Prediction')

############## visualizations #############
# feature importance based on SHAP
xpl.plot.features_importance()

# xpl.plot.compare_plot(row_num=[0,1,2])

# # contributions plot
# xpl.plot.contribution_plot("OverallQual")

# # Interactive interactions widget 
# xpl.plot.top_interactions_plot(nb_top_interactions=5)

# # save contributions
# predictor = xpl.to_smartpredictor()
# predictor.add_input(x=trainX, ypred=trainy)
# detailed_contributions = predictor.detail_contributions()
# Out:
# Backend: Shap TreeExplainer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-d22ed1aeb6ac> in <module>()
#       4 xpl.compile(
#       5     x=testX,
# ----> 6     model=modelxGBRegressor,
#       7 #     y_pred = predy
#       8 )
#
# /usr/local/lib/python3.7/dist-packages/shapash/explainer/smart_explainer.py in compile(self, x, model, explainer, contributions, y_pred, preprocessing, postprocessing, title_story, features_groups, backend, **kwargs)
#     239         adapt_contrib = self.adapt_contributions(contributions)
#     240         self.state = self.choose_state(adapt_contrib)
# --> 241         self.contributions = self.apply_preprocessing(self.validate_contributions(adapt_contrib), preprocessing)
#     242         self.check_contributions()
#     243         self.explainer = explainer
#
# ...

# %% [markdown]
# ### XAI Method 2: InterpretML

# %%
pip install interpret

# %%
# https://github.com/interpretml/interpret

from interpret import show
from interpret.data import Marginal
marginal = Marginal().explain_data(trainX, trainy, name = 'Train Data')
show(marginal)

# %%
seed=np.random.seed(0)

# %%
from interpret.glassbox import ExplainableBoostingRegressor, LinearRegression

modelILR = LinearRegression()
modelILR.fit(trainX, trainy)

modelIEBM = ExplainableBoostingRegressor()
modelIEBM.fit(trainX, trainy)

# %%
from interpret import show
from interpret.perf import RegressionPerf

performanceLR = RegressionPerf(modelILR.predict).explain_perf(testX, testy, name='Linear Regression')
performanceEBM = RegressionPerf(modelIEBM.predict).explain_perf(testX, testy, name='EBM')
show(performanceLR)
show(performanceEBM)

# %%
globalEBM = modelIEBM.explain_global(name='EBM')
show(globalEBM)

# %%
localEBM = modelIEBM.explain_local(testX[:5], testy[:5], name='EBM')
show(localEBM)

# %%
globalLR = modelILR.explain_global(name='Linear Regression')
show(globalLR)

# %%
localLR = modelILR.explain_local(testX[:5], testy[:5], name='Linear Regression')
show(localLR)

# %%
show([marginal, globalLR, localLR, performanceLR, globalEBM, localEBM, performanceEBM])
